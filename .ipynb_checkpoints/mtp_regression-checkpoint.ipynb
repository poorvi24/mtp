# %% [markdown]
# ## Regression
#
# This notebook shows the implementation of linear regression model and deriving mean absolute error for the data set **Advertising** taken from http://www-bcf.usc.edu/~gareth/ISL/data.html
#
# Libraries used are
#
# - pandas: for data analysis and handling
# - numpy: for numerical computation
# - matplotlib: for plotting data
# - sklearn: for regression, classification models

# %% [markdown]
# #### Data Description
#
# There are 3 features *TV*, *Newspaper*, *Radio* and one response variable *Sales* having 200 data points.
#
# Model is:
# $y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 + \beta_3 x_3 $

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Advertising.csv',index_col=0)
data
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# 6      8.7   48.9       75.0    7.2
# 7     57.5   32.8       23.5   11.8
# 8    120.2   19.6       11.6   13.2
# 9      8.6    2.1        1.0    4.8
# 10   199.8    2.6       21.2   10.6
# 11    66.1    5.8       24.2    8.6
# 12   214.7   24.0        4.0   17.4
# 13    23.8   35.1       65.9    9.2
# 14    97.5    7.6        7.2    9.7
# 15   204.1   32.9       46.0   19.0
# 16   195.4   47.7       52.9   22.4
# 17    67.8   36.6      114.0   12.5
# 18   281.4   39.6       55.8   24.4
# 19    69.2   20.5       18.3   11.3
# 20   147.3   23.9       19.1   14.6
# 21   218.4   27.7       53.4   18.0
# 22   237.4    5.1       23.5   12.5
# 23    13.2   15.9       49.6    5.6
# 24   228.3   16.9       26.2   15.5
# 25    62.3   12.6       18.3    9.7
# 26   262.9    3.5       19.5   12.0
# 27   142.9   29.3       12.6   15.0
# 28   240.1   16.7       22.9   15.9
# 29   248.8   27.1       22.9   18.9
# 30    70.6   16.0       40.8   10.5
# ..     ...    ...        ...    ...
# 171   50.0   11.6       18.4    8.4
# 172  164.5   20.9       47.4   14.5
# 173   19.6   20.1       17.0    7.6
# 174  168.4    7.1       12.8   11.7
# 175  222.4    3.4       13.1   11.5
# 176  276.9   48.9       41.8   27.0
# 177  248.4   30.2       20.3   20.2
# 178  170.2    7.8       35.2   11.7
# 179  276.7    2.3       23.7   11.8
# 180  165.6   10.0       17.6   12.6
# 181  156.6    2.6        8.3   10.5
# 182  218.5    5.4       27.4   12.2
# 183   56.2    5.7       29.7    8.7
# 184  287.6   43.0       71.8   26.2
# 185  253.8   21.3       30.0   17.6
# 186  205.0   45.1       19.6   22.6
# 187  139.5    2.1       26.6   10.3
# 188  191.1   28.7       18.2   17.3
# 189  286.0   13.9        3.7   15.9
# 190   18.7   12.1       23.4    6.7
# 191   39.5   41.1        5.8   10.8
# 192   75.5   10.8        6.0    9.9
# 193   17.2    4.1       31.6    5.9
# 194  166.8   42.0        3.6   19.6
# 195  149.7   35.6        6.0   17.3
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data.shape
# Out:
# (200, 4)

# %%
feature_col=['TV','Radio','Newspaper']
X=data[feature_col]
X.head()
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
X.shape
# Out:
# (200, 3)

# %%
y=data['Sales']
y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
y.shape
# Out:
# (200,)

# %%
from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
print X_train.shape
print X_test.shape
print y_train.shape
print y_test.shape
# Out:
# (150, 3)
# (50, 3)
# (150,)
# (50,)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print linreg.intercept_
print linreg.coef_
# Out:
# 2.76060616967
# [ 0.0459298   0.19816317 -0.00422984]

# %%
zip(feature_col,linreg.coef_)
# Out:
# [('TV', 0.045929799469669852),
#  ('Radio', 0.19816316805419559),
#  ('Newspaper', -0.0042298398998196988)]

# %%
y_pred=linreg.predict(X_test)

# %%
from sklearn import metrics
MAD= metrics.mean_absolute_error(y_test,y_pred)
print MAD
# Out:
# 1.18932593939

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import spline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['axes']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fig1=plt.figure(figsize=(8,7))
axes1=fig1.add_subplot(111)
a=np.arange(30)
axes1.plot(y_pred,y_test, color='red',linestyle='',marker='o')
axes1.plot(a,a, color='b',linestyle='-')
axes1.set_xlabel('Predicted Sales')
axes1.set_ylabel('Actual Sales')
axes1.set_title("$45^o plot$")
axes1.grid()
plt.show()

# %%
w=np.ravel(y_test)
w
# Out:
# array([ 11.7,  25.4,  10.8,  15. ,  12.5,  20.2,  20.7,  15.9,  12. ,
#         15.9,   8.1,   9.5,  13.2,  18.4,   8.7,   9.7,   5.3,  18.9,
#         12.4,  19.4,  19. ,   9.3,   9.7,  10.4,   9.9,  17.3,  15.2,
#         11.9,  17.1,  10.7,   5.9,  12. ,  21.8,  16.9,  15.2,   9.7,
#         10.1,  21.2,  20.1,  10.3,  10.4,   9.7,  11.6,  14.7,  14.1,
#         10.9,   3.2,   5.7,  14.6,  17.4])

# %%
y_pred
# Out:
# array([ 11.84800094,  23.45334673,  12.69480638,  17.89190676,
#         12.64521678,  20.46620928,  20.47566292,  15.51119954,
#         15.44663966,  16.42439411,   5.5236582 ,  11.62543508,
#         12.75076234,  18.24449086,   6.87397671,   7.99616071,
#          3.33326791,  19.06729945,  10.50334553,  19.14842909,
#         18.45987384,  12.35316023,   8.71434685,   8.54888676,
#          8.34308921,  16.66552689,  15.21856008,  13.84620849,
#         17.08689696,   9.25909703,   4.22940477,  11.64685955,
#         21.2939068 ,  16.29914   ,  15.00254524,   8.04148252,
#          9.88266973,  20.05423431,  19.3068332 ,   9.47144211,
#         12.40152897,   7.69367414,   9.77668931,  15.78751901,
#         13.87203311,  12.44157913,   5.22350101,   8.52757199,
#         15.48042328,  17.36073079])

# %%
x=np.arange(1,51)
pf=pd.DataFrame(x,columns=['x'])
pf['y_predicted']=y_pred
pf['y_actual']=w
pf
# Out:
#      x  y_predicted  y_actual
# 0    1    11.848001      11.7
# 1    2    23.453347      25.4
# 2    3    12.694806      10.8
# 3    4    17.891907      15.0
# 4    5    12.645217      12.5
# 5    6    20.466209      20.2
# 6    7    20.475663      20.7
# 7    8    15.511200      15.9
# 8    9    15.446640      12.0
# 9   10    16.424394      15.9
# 10  11     5.523658       8.1
# 11  12    11.625435       9.5
# 12  13    12.750762      13.2
# 13  14    18.244491      18.4
# 14  15     6.873977       8.7
# 15  16     7.996161       9.7
# 16  17     3.333268       5.3
# 17  18    19.067299      18.9
# 18  19    10.503346      12.4
# 19  20    19.148429      19.4
# 20  21    18.459874      19.0
# 21  22    12.353160       9.3
# 22  23     8.714347       9.7
# 23  24     8.548887      10.4
# 24  25     8.343089       9.9
# 25  26    16.665527      17.3
# 26  27    15.218560      15.2
# 27  28    13.846208      11.9
# 28  29    17.086897      17.1
# 29  30     9.259097      10.7
# 30  31     4.229405       5.9
# 31  32    11.646860      12.0
# 32  33    21.293907      21.8
# 33  34    16.299140      16.9
# 34  35    15.002545      15.2
# 35  36     8.041483       9.7
# 36  37     9.882670      10.1
# 37  38    20.054234      21.2
# 38  39    19.306833      20.1
# 39  40     9.471442      10.3
# 40  41    12.401529      10.4
# 41  42     7.693674       9.7
# 42  43     9.776689      11.6
# 43  44    15.787519      14.7
# 44  45    13.872033      14.1
# 45  46    12.441579      10.9
# 46  47     5.223501       3.2
# 47  48     8.527572       5.7
# 48  49    15.480423      14.6
# 49  50    17.360731      17.4

# %%
fig2=plt.figure(figsize=(10,15))
axes=fig2.add_subplot(211)
axes.plot(pf['x'],pf['y_predicted'],'go',linestyle='-',label='predicted')
axes.plot(pf['x'],pf['y_actual'],'b^',linestyle='-',label='actual')
axes.set_xlabel('data_points')
axes.set_ylabel('Sales')
axes.set_title("MAD=%f" %(MAD))
axes.legend(loc='upper right', bbox_to_anchor=(1, 1.05))
axes.grid()

axes=fig2.add_subplot(212)
axes.plot(pf['x'],pf['y_predicted'],'g',linestyle='-',label='predicted')
axes.plot(pf['x'],pf['y_actual'],'b',linestyle='-',label='actual')
axes.set_xlabel('data_points')
axes.set_ylabel('Sales')
axes.legend(loc='upper right', bbox_to_anchor=(1, 1.05))
axes.grid()
plt.show()
